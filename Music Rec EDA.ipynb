# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Music Genre 2022 (Responses).csv')
df=df.drop(columns=["Q1", "Q2", "Q3", "Q4", "Q5", "Q6", "Q7", "Q8", "Q9", "Q10"])
df.head()
# Out:
#    Age  Gender   Region            Profession  Extraversion  Agreeableness  \
# 0   23  Female     City               Student           2.5            3.0
# 1   23  Female     City               Student           4.5            2.0
# 2   25  Female  Village  Currently unemployed           7.0            4.0
# 3   23  Female     City               Student           3.0            6.0
# 4   24  Female     City            Job-holder           5.0            7.0
#
#    Conscientiousness  Stability  Openness              Happy  \
# 0                4.0        5.0       5.0                Pop
# 1                2.0        4.5       2.0  Dance/Electronica
# 2                2.0        2.0       7.0            Hip-hop
# 3                3.0        6.0       5.0  Dance/Electronica
# 4                4.5        6.5       1.5  Dance/Electronica
#
#                    Gloomy    Stressed          Energetic  \
# 0          Indie/Acoustic         Pop            Hip-hop
# ...

# %%
df.describe()
# Out:
#               Age  Extraversion  Agreeableness  Conscientiousness   Stability  \
# count  150.000000    150.000000     150.000000         150.000000  150.000000
# mean    23.700000      3.690000       4.816667           4.446667    4.250000
# std      3.776917      1.409067       1.160619           1.475922    1.400803
# min     17.000000      1.000000       2.000000           1.000000    1.000000
# 25%     22.000000      2.625000       4.000000           3.500000    3.500000
# 50%     23.000000      4.000000       4.750000           4.500000    4.000000
# 75%     25.000000      4.500000       5.500000           5.500000    5.500000
# max     47.000000      7.000000       7.000000           7.000000    7.000000
#
#          Openness
# count  150.000000
# mean     4.806667
# std      1.388818
# min      1.500000
# 25%      4.000000
# 50%      5.000000
# 75%      6.000000
# max      7.000000

# %%
#Checking number of unique values and wrong entries like symbols -,?,#,*,etc.
for col in df.columns:
    print('{} : {}'.format(col,df[col].unique()))
# Out:
# Age : [23 25 24 22 20 21 17 26 29 30 27 28 32 19 31 18 34 47]
# Gender : ['Female' 'Male' 'Other / Prefer not to say']
# Region : ['City' 'Village' 'Suburbs']
# Profession : ['Student' 'Currently unemployed' 'Job-holder']
# Extraversion : [2.5 4.5 7.  3.  5.  4.  1.5 3.5 2.  1.  6.  5.5 6.5]
# Agreeableness : [3.  2.  4.  6.  7.  3.5 6.5 5.5 5.  4.5 2.5]
# Conscientiousness : [4.  2.  3.  4.5 6.5 5.  5.5 7.  3.5 6.  2.5 1.5 1. ]
# Stability : [5.  4.5 2.  6.  6.5 3.  4.  1.5 3.5 1.  5.5 7.  2.5]
# Openness : [5.  2.  7.  1.5 3.  4.  5.5 6.  4.5 3.5 2.5 6.5]
# Happy : ['Pop' 'Dance/Electronica' 'Hip-hop' 'Indie/Acoustic'
#  'Classical/Instrumental' 'Rock/Metal' 'Country' 'Blues/Jazz']
# Gloomy : ['Indie/Acoustic' 'Classical/Instrumental' 'Blues/Jazz' 'Rock/Metal' 'Pop'
#  'Hip-hop' 'Country' 'Dance/Electronica']
# Stressed : ['Pop' 'Blues/Jazz' 'Hip-hop' 'Indie/Acoustic' 'Dance/Electronica'
#  'Country' 'Rock/Metal' 'Classical/Instrumental']
# ...

# %%
df['Gender'].value_counts().plot(kind='pie',autopct="%.2f")
# Out:
# <AxesSubplot:ylabel='Gender'>

# %%
df['Profession'].value_counts().plot(kind='pie',autopct="%.2f")
# Out:
# <AxesSubplot:ylabel='Profession'>

# %%
sns.histplot(data=df, x='Age')
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Count'>

# %%
sns.scatterplot(df['Age'], df['Conscientiousness'], hue=df['Gender'])
# Out:
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Age', ylabel='Conscientiousness'>

# %%
sns.histplot(data=df, x='Extraversion')
# Out:
# <AxesSubplot:xlabel='Extraversion', ylabel='Count'>

# %%
sns.histplot(data=df, x='Agreeableness')
# Out:
# <AxesSubplot:xlabel='Agreeableness', ylabel='Count'>

# %%
sns.histplot(data=df, x='Conscientiousness')
# Out:
# <AxesSubplot:xlabel='Conscientiousness', ylabel='Count'>

# %%
sns.histplot(data=df, x='Stability')
# Out:
# <AxesSubplot:xlabel='Stability', ylabel='Count'>

# %%
sns.histplot(data=df, x='Openness')
# Out:
# <AxesSubplot:xlabel='Openness', ylabel='Count'>

# %%
#Distribution of genre by pie-chart
df['Happy'].value_counts().plot(kind="pie", autopct="%.2f")
plt.show()

# %%
pd.DataFrame(df['Happy'].value_counts()).style.bar(color='thistle')
# Out:
# <style type="text/css">
# #T_48ed5_row0_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, thistle 100.0%, transparent 100.0%);
# }
# #T_48ed5_row1_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, thistle 45.2%, transparent 45.2%);
# }
# #T_48ed5_row2_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, thistle 30.6%, transparent 30.6%);
# }
# #T_48ed5_row3_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, thistle 22.6%, transparent 22.6%);
# }
# #T_48ed5_row4_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, thistle 21.0%, transparent 21.0%);
# }
# #T_48ed5_row5_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, thistle 12.9%, transparent 12.9%);
# }
# #T_48ed5_row6_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, thistle 8.1%, transparent 8.1%);
# }
# #T_48ed5_row7_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, thistle 1.6%, transparent 1.6%);
# }
# </style>
# ...

# %%
#Distribution of genre by pie-chart
df['Gloomy'].value_counts().plot(kind="pie", autopct="%.2f")
plt.show()

# %%
pd.DataFrame(df['Gloomy'].value_counts()).style.bar(color='powderblue')
# Out:
# <style type="text/css">
# #T_eb201_row0_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, powderblue 100.0%, transparent 100.0%);
# }
# #T_eb201_row1_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, powderblue 94.7%, transparent 94.7%);
# }
# #T_eb201_row2_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, powderblue 81.6%, transparent 81.6%);
# }
# #T_eb201_row3_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, powderblue 42.1%, transparent 42.1%);
# }
# #T_eb201_row4_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, powderblue 23.7%, transparent 23.7%);
# }
# #T_eb201_row5_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, powderblue 21.1%, transparent 21.1%);
# }
# #T_eb201_row6_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, powderblue 18.4%, transparent 18.4%);
# }
# #T_eb201_row7_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, powderblue 13.2%, transparent 13.2%);
# }
# ...

# %%
#Distribution of genre by pie-chart
df['Stressed'].value_counts().plot(kind="pie", autopct="%.2f")
plt.show()

# %%
pd.DataFrame(df['Stressed'].value_counts()).style.bar(color='powderblue')
# Out:
# <style type="text/css">
# #T_7cdd3_row0_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, powderblue 100.0%, transparent 100.0%);
# }
# #T_7cdd3_row1_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, powderblue 56.1%, transparent 56.1%);
# }
# #T_7cdd3_row2_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, powderblue 51.2%, transparent 51.2%);
# }
# #T_7cdd3_row3_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, powderblue 46.3%, transparent 46.3%);
# }
# #T_7cdd3_row4_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, powderblue 39.0%, transparent 39.0%);
# }
# #T_7cdd3_row5_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, powderblue 29.3%, transparent 29.3%);
# }
# #T_7cdd3_row6_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, powderblue 24.4%, transparent 24.4%);
# }
# #T_7cdd3_row7_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, powderblue 19.5%, transparent 19.5%);
# }
# ...

# %%
#Distribution of genre by pie-chart
df['Relaxed'].value_counts().plot(kind="pie", autopct="%.2f")
plt.show()

# %%
pd.DataFrame(df['Relaxed'].value_counts()).style.bar(color='powderblue')
# Out:
# <style type="text/css">
# #T_a6d9c_row0_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, powderblue 100.0%, transparent 100.0%);
# }
# #T_a6d9c_row1_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, powderblue 54.3%, transparent 54.3%);
# }
# #T_a6d9c_row2_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, powderblue 47.8%, transparent 47.8%);
# }
# #T_a6d9c_row3_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, powderblue 41.3%, transparent 41.3%);
# }
# #T_a6d9c_row4_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, powderblue 30.4%, transparent 30.4%);
# }
# #T_a6d9c_row5_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, powderblue 21.7%, transparent 21.7%);
# }
# #T_a6d9c_row6_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, powderblue 17.4%, transparent 17.4%);
# }
# #T_a6d9c_row7_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, powderblue 13.0%, transparent 13.0%);
# }
# ...

# %%
#Distribution of genre by pie-chart
df['Energetic'].value_counts().plot(kind="pie", autopct="%.2f")
plt.show()

# %%
pd.DataFrame(df['Energetic'].value_counts()).style.bar(color='powderblue')
# Out:
# <style type="text/css">
# #T_289d5_row0_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, powderblue 100.0%, transparent 100.0%);
# }
# #T_289d5_row1_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, powderblue 62.3%, transparent 62.3%);
# }
# #T_289d5_row2_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, powderblue 54.7%, transparent 54.7%);
# }
# #T_289d5_row3_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, powderblue 49.1%, transparent 49.1%);
# }
# #T_289d5_row4_col0, #T_289d5_row5_col0, #T_289d5_row6_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, powderblue 5.7%, transparent 5.7%);
# }
# </style>
# <table id="T_289d5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_289d5_level0_col0" class="col_heading level0 col0" >Energetic</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_289d5_level0_row0" class="row_heading level0 row0" >Rock/Metal</th>
# ...

# %%
sns.boxplot(data=df, x='Gender', y="Age")
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='Age'>

# %%
sns.catplot(data=df, x="Age", y="Profession",kind="violin", bw=.25, cut=0, split=True)

# %%
sns.displot(data=df, x='Age', y='Openness', color="blue", kind='kde') 
sns.displot(data=df,x='Age', y='Extraversion',hue="Gender")
plt.show()

# %%
#Boxplot between Age and Genre, coloured by Gender
sns.boxplot(x='Age',y='Happy',hue='Gender',data=df)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Happy'>

# %%
#Boxplot between Age and Genre, coloured by Gender
sns.boxplot(x='Extraversion',y='Happy',hue='Gender',data=df)
# Out:
# <AxesSubplot:xlabel='Extraversion', ylabel='Happy'>

# %%
#Relationship analysis
sns.heatmap(df.corr(),cbar=True, annot=True, cmap='Blues')
# Out:
# <AxesSubplot:>

# %%
#Correlation between which Genre is preferred by age groups when Relaxing
sns.heatmap(pd.crosstab(df['Age'], df['Happy']))
# Out:
# <AxesSubplot:xlabel='Happy', ylabel='Age'>

# %%
#Correlation between which Genre is preferred by age groups when Relaxing
sns.heatmap(pd.crosstab(df['Age'], df['Gloomy']))
# Out:
# <AxesSubplot:xlabel='Gloomy', ylabel='Age'>

# %%
#Correlation between which Genre is preferred by age groups when Relaxing
sns.heatmap(pd.crosstab(df['Agreeableness'], df['Happy']))
# Out:
# <AxesSubplot:xlabel='Happy', ylabel='Agreeableness'>

# %%
#Correlation between which Genre is preferred by age groups when Relaxing
sns.heatmap(pd.crosstab(df['Agreeableness'], df['Gloomy']))
# Out:
# <AxesSubplot:xlabel='Gloomy', ylabel='Agreeableness'>
