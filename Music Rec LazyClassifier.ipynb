# %%
import lazypredict
import pandas as pd
from lazypredict.Supervised import LazyClassifier
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('Music Genre 2022 (Responses).csv')
df=df.drop(columns=["Q1", "Q2", "Q3", "Q4", "Q5", "Q6", "Q7", "Q8", "Q9", "Q10"])
df.head()
# Out:
#    Age  Gender   Region            Profession  Extraversion  Agreeableness  \
# 0   23  Female     City               Student          2.50           3.00
# 1   23  Female     City               Student          4.50           2.00
# 2   25  Female  Village  Currently unemployed          7.00           4.00
# 3   23  Female     City               Student          3.00           6.00
# 4   24  Female     City            Job-holder          5.00           7.00
#
#    Conscientiousness  Stability  Openness              Happy  \
# 0               4.00       5.00      5.00                Pop
# 1               2.00       4.50      2.00  Dance/Electronica
# 2               2.00       2.00      7.00            Hip-hop
# 3               3.00       6.00      5.00  Dance/Electronica
# 4               4.50       6.50      1.50  Dance/Electronica
#
#                    Gloomy    Stressed          Energetic  \
# 0          Indie/Acoustic         Pop            Hip-hop
# ...

# %%
#Ordinal Encoder for mood
from category_encoders import OrdinalEncoder

mapping_1 = {}
mapping_2 = {}

maplist_1 = [{'col': 'Gender', 
            'mapping': mapping_1}]
maplist_2 = [{'col': 'Region', 
            'mapping': mapping_2}]

for category in sorted(list(df['Gender'].unique())):
    mapping_1[category] = sorted(list(df['Gender'].unique())).index(category)
     
for category in sorted(list(df['Region'].unique())):
    mapping_2[category] = sorted(list(df['Region'].unique())).index(category)

Ordinal_Encoder_1 = OrdinalEncoder(mapping=maplist_1)
Ordinal_Encoder_2 = OrdinalEncoder(mapping=maplist_2)

df = Ordinal_Encoder_1.fit_transform(df)
df = Ordinal_Encoder_2.fit_transform(df)

# %%
mapping_3 = {}
for category in sorted(list(df['Profession'].unique())):
    mapping_3[category] = sorted(list(df['Profession'].unique())).index(category)

mapping_3 = [{'col': 'Profession', 
            'mapping': mapping_3}]

Ordinal_Encoder_3 = OrdinalEncoder(mapping=mapping_3)

df = Ordinal_Encoder_3.fit_transform(df)
df.head(5)
# Out:
#    Age  Gender  Region  Profession  Extraversion  Agreeableness  \
# 0   23       0       0           2          2.50           3.00
# 1   23       0       0           2          4.50           2.00
# 2   25       0       2           0          7.00           4.00
# 3   23       0       0           2          3.00           6.00
# 4   24       0       0           1          5.00           7.00
#
#    Conscientiousness  Stability  Openness              Happy  \
# 0               4.00       5.00      5.00                Pop
# 1               2.00       4.50      2.00  Dance/Electronica
# 2               2.00       2.00      7.00            Hip-hop
# 3               3.00       6.00      5.00  Dance/Electronica
# 4               4.50       6.50      1.50  Dance/Electronica
#
#                    Gloomy    Stressed          Energetic  \
# 0          Indie/Acoustic         Pop            Hip-hop
# 1          Indie/Acoustic  Blues/Jazz         Rock/Metal
# ...

# %%
X=df[['Age','Gender', 'Region','Profession', 'Extraversion','Agreeableness','Conscientiousness', 'Stability','Openness']]

# %%
#Model testing for Happy
y=df['Happy']
X_train,X_test,y_train,y_test=train_test_split(X.values,y,test_size = 0.25, random_state = 1000)

clf = LazyClassifier(verbose=0,ignore_warnings=True, custom_metric=None)
happy_models,predictions = clf.fit(X_train, X_test, y_train, y_test)
happy_models
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 29/29 [00:02<00:00, 11.66it/s]
#                              Accuracy  Balanced Accuracy ROC AUC  F1 Score  \
# Model
# LGBMClassifier                   0.32               0.19    None      0.26
# DecisionTreeClassifier           0.29               0.18    None      0.28
# BernoulliNB                      0.26               0.18    None      0.20
# BaggingClassifier                0.29               0.18    None      0.25
# AdaBoostClassifier               0.37               0.17    None      0.22
# ExtraTreeClassifier              0.26               0.16    None      0.26
# KNeighborsClassifier             0.29               0.16    None      0.25
# RandomForestClassifier           0.32               0.16    None      0.23
# ExtraTreesClassifier             0.26               0.15    None      0.24
# ...

# %%
#Model testing for Gloomy
y=df['Gloomy']
X_train,X_test,y_train,y_test=train_test_split(X.values,y,test_size = 0.25, random_state = 1000)

clf = LazyClassifier(verbose=0,ignore_warnings=True, custom_metric=None)
gloomy_models,predictions = clf.fit(X_train, X_test, y_train, y_test)
gloomy_models
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 29/29 [00:02<00:00, 11.44it/s]
#                                Accuracy  Balanced Accuracy ROC AUC  F1 Score  \
# Model
# BaggingClassifier                  0.37               0.32    None      0.33
# ExtraTreesClassifier               0.34               0.30    None      0.30
# RandomForestClassifier             0.29               0.29    None      0.27
# BernoulliNB                        0.26               0.28    None      0.27
# SVC                                0.26               0.27    None      0.18
# NearestCentroid                    0.18               0.26    None      0.22
# AdaBoostClassifier                 0.16               0.21    None      0.13
# QuadraticDiscriminantAnalysis      0.13               0.20    None      0.14
# GaussianNB                         0.08               0.17    None      0.09
# ...

# %%
#Model testing for Energetic
y=df['Energetic']
X_train,X_test,y_train,y_test=train_test_split(X.values,y,test_size = 0.25, random_state = 1000)

clf = LazyClassifier(verbose=0,ignore_warnings=True, custom_metric=None)
ener_models,predictions = clf.fit(X_train, X_test, y_train, y_test)
ener_models
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 29/29 [00:02<00:00, 10.55it/s]
#                              Accuracy  Balanced Accuracy ROC AUC  F1 Score  \
# Model
# ExtraTreeClassifier              0.50               0.47    None      0.48
# LabelPropagation                 0.45               0.44    None      0.47
# LabelSpreading                   0.45               0.44    None      0.47
# ExtraTreesClassifier             0.45               0.40    None      0.42
# DecisionTreeClassifier           0.34               0.37    None      0.35
# BaggingClassifier                0.42               0.36    None      0.46
# RandomForestClassifier           0.42               0.35    None      0.43
# LGBMClassifier                   0.42               0.33    None      0.43
# GaussianNB                       0.16               0.26    None      0.18
# ...

# %%
#Model testing for Stressed
y=df['Stressed']
X_train,X_test,y_train,y_test=train_test_split(X.values,y,test_size = 0.25, random_state = 1000)

clf = LazyClassifier(verbose=0,ignore_warnings=True, custom_metric=None)
stress_models,predictions = clf.fit(X_train, X_test, y_train, y_test)
stress_models
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 29/29 [00:02<00:00, 11.48it/s]
#                                Accuracy  Balanced Accuracy ROC AUC  F1 Score  \
# Model
# ExtraTreesClassifier               0.29               0.21    None      0.27
# QuadraticDiscriminantAnalysis      0.18               0.19    None      0.16
# RandomForestClassifier             0.24               0.19    None      0.23
# LGBMClassifier                     0.18               0.17    None      0.19
# BaggingClassifier                  0.16               0.17    None      0.16
# AdaBoostClassifier                 0.29               0.17    None      0.22
# SVC                                0.32               0.16    None      0.20
# KNeighborsClassifier               0.16               0.15    None      0.16
# BernoulliNB                        0.21               0.14    None      0.21
# ...

# %%
#Model testing for Relaxed
y=df['Relaxed']
X_train,X_test,y_train,y_test=train_test_split(X.values,y,test_size = 0.25, random_state = 1000)

clf = LazyClassifier(verbose=0,ignore_warnings=True, custom_metric=None)
relax_models,predictions = clf.fit(X_train, X_test, y_train, y_test)
relax_models
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 29/29 [00:02<00:00, 11.39it/s]
#                                Accuracy  Balanced Accuracy ROC AUC  F1 Score  \
# Model
# ExtraTreesClassifier               0.37               0.29    None      0.36
# LGBMClassifier                     0.32               0.22    None      0.28
# RandomForestClassifier             0.32               0.20    None      0.27
# GaussianNB                         0.16               0.20    None      0.11
# KNeighborsClassifier               0.32               0.20    None      0.26
# BaggingClassifier                  0.29               0.19    None      0.28
# QuadraticDiscriminantAnalysis      0.29               0.19    None      0.24
# BernoulliNB                        0.24               0.18    None      0.23
# SVC                                0.32               0.18    None      0.24
# ...
